# %% [markdown]
# ### Assignment 5
#
# You will unzip the zip file manually in preparation for this assignment.
#
# The link to the zip file is (you have already used it in your assignment 3):
#
# https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip
#
# After unzipping, You will have all files in one folder named "CollegeScorecard_Raw_Data"
#
# The folder contains the yearly data files from 1996 to 2017 school years.
#
# Your Jupyter Notebook file should not be in the CollegeScorecard_Raw_Data folder.
#
# I suggest you create a new folder call "Assignment4" and place the Notebook file and the data folder under it.
#
# Assignment4/
#     - Jay.ipynb
#     - CollegeScorecard_Raw_Data/
#         - ...
#         - 'MERGED1996_97_PP.csv',
#         - 'MERGED2015_16_PP.csv',
#         - ...
#         - 'MERGED2017_18_PP.csv'

# %%
# <1> 
# Import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# <2>
# Find out what files are in the folder and assign the list of files to a variable for later processing
# you would need to import a library call os which stands for operating system. so place that import statement in previous cell.
# # os library also has method getcwd() to get the current working directory. since your notebook and your data files are not in 
# the same folder, you want to make sure what is the current working folder and how to access a data file in a different folder
# display the current workin directory
DATA_FOLDER = 'CollegeScorecard_Raw_data'
file_names = os.listdir(DATA_FOLDER)
file_names
# Out:
# ['.DS_Store',
#  'Crosswalks.zip',
#  'data.yaml',
#  'FieldOfStudyData1415_1516_PP.csv',
#  'FieldOfStudyData1516_1617_PP.csv',
#  'MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2018_19_PP.csv']

# %%
filename = "MERGED1998_99_PP"
filename[6:10]
# Out:
# '1998'

# %%
# <3> 
# os library has a method call listdir which generates a list of files in a directory/folder
# use this method to assign the contents of the data folder to a variable and display it
os.getcwd()
# Out:
# 'C:\\Users\\sures\\OneDrive\\Desktop\\690'

# %%
# <4> 
# The folder contains a couple of files that are not the yearly data files
# write code to remove the unwanted files from the list (Note: not from the folder in your drive)
# hint: use pop or remove functions of a list. pop and remove work differently though.
csv_files=[name for name in file_names if name.startswith('MERGED')]
csv_files
# Out:
# ['MERGED1996_97_PP.csv',
#  'MERGED1997_98_PP.csv',
#  'MERGED1998_99_PP.csv',
#  'MERGED1999_00_PP.csv',
#  'MERGED2000_01_PP.csv',
#  'MERGED2001_02_PP.csv',
#  'MERGED2002_03_PP.csv',
#  'MERGED2003_04_PP.csv',
#  'MERGED2004_05_PP.csv',
#  'MERGED2005_06_PP.csv',
#  'MERGED2006_07_PP.csv',
#  'MERGED2007_08_PP.csv',
#  'MERGED2008_09_PP.csv',
#  'MERGED2009_10_PP.csv',
#  'MERGED2010_11_PP.csv',
#  'MERGED2011_12_PP.csv',
#  'MERGED2012_13_PP.csv',
#  'MERGED2013_14_PP.csv',
#  'MERGED2014_15_PP.csv',
#  'MERGED2015_16_PP.csv',
#  'MERGED2016_17_PP.csv',
#  'MERGED2017_18_PP.csv',
#  'MERGED2018_19_PP.csv']

# %%
# <5> 
# Now that you have a clean list of the yearly files, you want to loop through them
# and read them into a dataframe one at a time. You only load three columns: UNITID, ADM_RATE, and TUITIONFEE_IN
# You also want to add a new column call "YEAR" to differentiate the data frames from each other.
# You would use an empty list and append the yearly dataframes to the list.
# After all data files are loaded and appended to the list, you would use Pandas to concatenate them into a 
# new single data frame.
# Note: this exercise incorporates many techques we learned before
# - list (creating an empty, append an item to the list)
# - for loop 
# - read only the needed columns from a file (using usecols option)
# - add a new column to a data frame
# - concatenate multiple dataframes into a single one
# This exercise may appear a big challenging but it worths the effort. You will learn a lot and  love it. I promise.
df_list=[]

for csv_file in csv_files:
    df=pd.read_csv(DATA_FOLDER + "/"+ csv_file ,usecols=["UNITID","INSTNM","ADM_RATE","TUITIONFEE_IN"])
    df['year']=csv_file[6:10]
    df_list.append(df)
    
    print("processing file:", csv_file)
df_list
# Out:
# processing file: MERGED1996_97_PP.csv
# processing file: MERGED1997_98_PP.csv
# processing file: MERGED1998_99_PP.csv
# processing file: MERGED1999_00_PP.csv
# processing file: MERGED2000_01_PP.csv
# processing file: MERGED2001_02_PP.csv
# processing file: MERGED2002_03_PP.csv
# processing file: MERGED2003_04_PP.csv
# processing file: MERGED2004_05_PP.csv
# processing file: MERGED2005_06_PP.csv
# processing file: MERGED2006_07_PP.csv
# processing file: MERGED2007_08_PP.csv
# processing file: MERGED2008_09_PP.csv
# processing file: MERGED2009_10_PP.csv
# processing file: MERGED2010_11_PP.csv
# processing file: MERGED2011_12_PP.csv
# processing file: MERGED2012_13_PP.csv
# processing file: MERGED2013_14_PP.csv
# processing file: MERGED2014_15_PP.csv
# processing file: MERGED2015_16_PP.csv
# processing file: MERGED2016_17_PP.csv
# processing file: MERGED2017_18_PP.csv
# processing file: MERGED2018_19_PP.csv
# [      UNITID                                           INSTNM  ADM_RATE  \
#  0     100636               Community College of the Air Force       NaN
#  1     100654                         Alabama A & M University       NaN
#  2     100663              University of Alabama at Birmingham       NaN
#  3     100672           ALABAMA AVIATION AND TECHNICAL COLLEGE       NaN
#  4     100690                               Amridge University       NaN
#  ...      ...                                              ...       ...
#  7002  428347  American Institute of Medical-Dental Technology       NaN
#  7003  428365          INSTITUTO DE ESTETICA Y BELLAZA MARUGIE       NaN
#  7004  428374                           KEISER COLLEGE-DAYTONA       NaN
#  7005  428392                        Klamath Community College       NaN
#  7006  428444                     The Art Institute of Phoenix       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  1996
#  1               NaN  1996
#  2               NaN  1996
#  3               NaN  1996
#  4               NaN  1996
#  ...             ...   ...
#  7002            NaN  1996
#  7003            NaN  1996
#  7004            NaN  1996
#  7005            NaN  1996
#  7006            NaN  1996
#
#  [7007 rows x 5 columns],
#        UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100636      Community College of the Air Force       NaN            NaN
#  1     100654                Alabama A & M University       NaN            NaN
#  2     100663     University of Alabama at Birmingham       NaN            NaN
#  3     100672  ALABAMA AVIATION AND TECHNICAL COLLEGE       NaN            NaN
#  4     100690                      Amridge University       NaN            NaN
#  ...      ...                                     ...       ...            ...
#  6929  432418                 MANHATTAN BEAUTY SCHOOL       NaN            NaN
#  6930  432436                 COOPER CAREER INSTITUTE       NaN            NaN
#  6931  432445            OCCUPATIONAL TRAINING CENTER       NaN            NaN
#  6932  432472  ABC SPA CITY BEAUTY AND BARBER COLLEGE       NaN            NaN
#  6933  432524      Delaware College of Art and Design       NaN            NaN
#
#        year
#  0     1997
#  1     1997
#  2     1997
#  3     1997
#  4     1997
#  ...    ...
#  6929  1997
#  6930  1997
#  6931  1997
#  6932  1997
#  6933  1997
#
#  [6934 rows x 5 columns],
#        UNITID                                       INSTNM  ADM_RATE  \
#  0     100654                     Alabama A & M University       NaN
#  1     100663          University of Alabama at Birmingham       NaN
#  2     100690                           Amridge University       NaN
#  3     100706          University of Alabama in Huntsville       NaN
#  4     100724                     Alabama State University       NaN
#  ...      ...                                          ...       ...
#  6697  434779                  WATERMAN TRAINING INSTITUTE       NaN
#  6698  434849                                CSC Institute       NaN
#  6699  434867    CENTER FOR EMPLOYMENT TRAINING-SANTA ROSA       NaN
#  6700  434876  CENTER FOR EMPLOYMENT TRAINING-TRACY CAMPUS       NaN
#  6701  434900                    Dewey University-Carolina       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  1998
#  1               NaN  1998
#  2               NaN  1998
#  3               NaN  1998
#  4               NaN  1998
#  ...             ...   ...
#  6697            NaN  1998
#  6698            NaN  1998
#  6699            NaN  1998
#  6700            NaN  1998
#  6701            NaN  1998
#
#  [6702 rows x 5 columns],
#        UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100654                Alabama A & M University       NaN            NaN
#  1     100663     University of Alabama at Birmingham       NaN            NaN
#  2     100690                      Amridge University       NaN            NaN
#  3     100706     University of Alabama in Huntsville       NaN            NaN
#  4     100724                Alabama State University       NaN            NaN
#  ...      ...                                     ...       ...            ...
#  6604  436784  Universal Career Community College Inc       NaN            NaN
#  6605  436809                       Willsey Institute       NaN            NaN
#  6606  437042      ITT Technical Institute-Saint Rose       NaN            NaN
#  6607  437413              EURO HAIR DESIGN INSTITUTE       NaN            NaN
#  6608  437431          BUCKS COUNTY COMMUNITY COLLEGE       NaN            NaN
#
#        year
#  0     1999
#  1     1999
#  2     1999
#  3     1999
#  4     1999
#  ...    ...
#  6604  1999
#  6605  1999
#  6606  1999
#  6607  1999
#  6608  1999
#
#  [6609 rows x 5 columns],
#        UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100636      Community College of the Air Force       NaN            NaN
#  1     100654                Alabama A & M University       NaN         4664.0
#  2     100663     University of Alabama at Birmingham       NaN         3363.0
#  3     100690                      Amridge University       NaN            NaN
#  4     100706     University of Alabama in Huntsville       NaN         3112.0
#  ...      ...                                     ...       ...            ...
#  6649  439109  STRAYER UNIVERSITY-CHESTERFIELD CAMPUS       NaN         8505.0
#  6650  439118              Carrington College-Spokane       NaN            NaN
#  6651  439127          Brightwood College-Friendswood       NaN            NaN
#  6652  439260    KELLER GRADUATE SCHOOL OF MANAGEMENT       NaN            NaN
#  6653  439321                       Ave Maria College       NaN         6040.0
#
#        year
#  0     2000
#  1     2000
#  2     2000
#  3     2000
#  4     2000
#  ...    ...
#  6649  2000
#  6650  2000
#  6651  2000
#  6652  2000
#  6653  2000
#
#  [6654 rows x 5 columns],
#        UNITID                               INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0     100636   Community College of the Air Force       NaN            NaN
#  1     100654             Alabama A & M University    0.7505         4664.0
#  2     100663  University of Alabama at Birmingham    0.9098         3640.0
#  3     100690                   Amridge University       NaN            NaN
#  4     100706  University of Alabama in Huntsville    0.8381         3536.0
#  ...      ...                                  ...       ...            ...
#  6720  440855             Milan Institute-Amarillo    1.0000            NaN
#  6721  440864                      Trinity College    1.0000            NaN
#  6722  440873           Vatterott College-Dividend    0.9091         7520.0
#  6723  440882              Vatterott College-Tulsa    0.9106         6715.0
#  6724  440891            Vatterott College-Wichita    0.8654         8380.0
#
#        year
#  0     2001
#  1     2001
#  2     2001
#  3     2001
#  4     2001
#  ...    ...
#  6720  2001
#  6721  2001
#  6722  2001
#  6723  2001
#  6724  2001
#
#  [6725 rows x 5 columns],
#        UNITID                                             INSTNM  ADM_RATE  \
#  0     100636                 Community College of the Air Force       NaN
#  1     100654                           Alabama A & M University    0.5575
#  2     100663                University of Alabama at Birmingham    0.9117
#  3     100690                                 Amridge University       NaN
#  4     100706                University of Alabama in Huntsville    0.9050
#  ...      ...                                                ...       ...
#  6647  442444                 San Joaquin Valley College-Ontario       NaN
#  6648  442462                       Anthem Institute-Cherry Hill    0.6650
#  6649  442499                          Westwood College-Ft Worth    0.7727
#  6650  442505                            Westwood College-Dallas       NaN
#  6651  442514  CoxHealth School of Diagnostic Medical Sonography       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2002
#  1            3040.0  2002
#  2            3880.0  2002
#  3            8960.0  2002
#  4            3764.0  2002
#  ...             ...   ...
#  6647         4925.0  2002
#  6648            NaN  2002
#  6649        10065.0  2002
#  6650        10065.0  2002
#  6651            NaN  2002
#
#  [6652 rows x 5 columns],
#        UNITID                                             INSTNM  ADM_RATE  \
#  0     100636                 Community College of the Air Force       NaN
#  1     100654                           Alabama A & M University    0.4457
#  2     100663                University of Alabama at Birmingham    0.8049
#  3     100690                                 Amridge University       NaN
#  4     100706                University of Alabama in Huntsville    0.8756
#  ...      ...                                                ...       ...
#  6668  444042             National University College-Rio Grande    0.8782
#  6669  444051  Creative Images Institute of Cosmetology-South...       NaN
#  6670  444060                     Westwood College-Houston South    0.9500
#  6671  444079                      Fortis Institute-Jacksonville       NaN
#  6672  444088                      Brookline College-Albuquerque       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2003
#  1            3352.0  2003
#  2            4274.0  2003
#  3            9440.0  2003
#  4            4126.0  2003
#  ...             ...   ...
#  6668         4480.0  2003
#  6669            NaN  2003
#  6670        10938.0  2003
#  6671            NaN  2003
#  6672            NaN  2003
#
#  [6673 rows x 5 columns],
#          UNITID                               INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0       100636   Community College of the Air Force       NaN            NaN
#  1       100654             Alabama A & M University    0.4751         4420.0
#  2       100663  University of Alabama at Birmingham    0.8592         4662.0
#  3       100690                   Amridge University       NaN        10040.0
#  4       100706  University of Alabama in Huntsville    0.8944         4516.0
#  ...        ...                                  ...       ...            ...
#  6742  42171701               SENTINEL CAREER CENTER       NaN            NaN
#  6743  42211801               DE MARGE COLLEGE NORTH       NaN            NaN
#  6744  42312001    Compu-Med Vocational Careers Corp       NaN         4600.0
#  6745  42817001     Southeastern College-Miami Lakes       NaN        11408.0
#  6746  42817002  Southeastern College-St. Petersburg       NaN        11408.0
#
#        year
#  0     2004
#  1     2004
#  2     2004
#  3     2004
#  4     2004
#  ...    ...
#  6742  2004
#  6743  2004
#  6744  2004
#  6745  2004
#  6746  2004
#
#  [6747 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100636                 Community College of the Air Force       NaN
#  1       100654                           Alabama A & M University    0.4199
#  2       100663                University of Alabama at Birmingham    0.8769
#  3       100690                                 Amridge University       NaN
#  4       100706                University of Alabama in Huntsville    0.8716
#  ...        ...                                                ...       ...
#  6894  43821203             McCann School of Business & Technology       NaN
#  6895  44098901            Texas Barber College - Branch Campus #1       NaN
#  6896  44098902            Texas Barber College - Branch Campus #2       NaN
#  6897  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6898  44098904            Texas Barber College - Branch Campus #5       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2005
#  1            4420.0  2005
#  2            4792.0  2005
#  3           10400.0  2005
#  4            4688.0  2005
#  ...             ...   ...
#  6894         8928.0  2005
#  6895            NaN  2005
#  6896            NaN  2005
#  6897            NaN  2005
#  6898            NaN  2005
#
#  [6899 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100636                 Community College of the Air Force       NaN
#  1       100654                           Alabama A & M University    0.4118
#  2       100663                University of Alabama at Birmingham    0.8778
#  3       100690                                 Amridge University       NaN
#  4       100706                University of Alabama in Huntsville    0.8834
#  ...        ...                                                ...       ...
#  6946  44098901            Texas Barber College - Branch Campus #1       NaN
#  6947  44098902            Texas Barber College - Branch Campus #2       NaN
#  6948  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6949  44098904            Texas Barber College - Branch Campus #5       NaN
#  6950  44098905  Texas Barber Colleges and Hairstyling Schools ...       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2006
#  1            3640.0  2006
#  2            4792.0  2006
#  3            6000.0  2006
#  4            4848.0  2006
#  ...             ...   ...
#  6946            NaN  2006
#  6947            NaN  2006
#  6948            NaN  2006
#  6949            NaN  2006
#  6950            NaN  2006
#
#  [6951 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100636                 Community College of the Air Force       NaN
#  1       100654                           Alabama A & M University    0.3182
#  2       100663                University of Alabama at Birmingham    0.8778
#  3       100690                                 Amridge University       NaN
#  4       100706                University of Alabama in Huntsville    0.8800
#  ...        ...                                                ...       ...
#  6966  44098901            Texas Barber College - Branch Campus #1       NaN
#  6967  44098902            Texas Barber College - Branch Campus #2       NaN
#  6968  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  6969  44098904            Texas Barber College - Branch Campus #5       NaN
#  6970  44098905  Texas Barber Colleges and Hairstyling Schools ...       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2007
#  1            4072.0  2007
#  2            4208.0  2007
#  3            6240.0  2007
#  4            5216.0  2007
#  ...             ...   ...
#  6966            NaN  2007
#  6967            NaN  2007
#  6968            NaN  2007
#  6969            NaN  2007
#  6970            NaN  2007
#
#  [6971 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100636                 Community College of the Air Force       NaN
#  1       100654                           Alabama A & M University    0.4900
#  2       100663                University of Alabama at Birmingham    0.8510
#  3       100690                                 Amridge University       NaN
#  4       100706                University of Alabama in Huntsville    0.8917
#  ...        ...                                                ...       ...
#  7050  44098901            Texas Barber College - Branch Campus #1       NaN
#  7051  44098902            Texas Barber College - Branch Campus #2       NaN
#  7052  44098903  Texas Barber Colleges and Hairstyling Schools ...       NaN
#  7053  44098904            Texas Barber College - Branch Campus #5       NaN
#  7054  44098905  Texas Barber Colleges and Hairstyling Schools ...       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2008
#  1            4072.0  2008
#  2            4664.0  2008
#  3            6600.0  2008
#  4            5952.0  2008
#  ...             ...   ...
#  7050            NaN  2008
#  7051            NaN  2008
#  7052            NaN  2008
#  7053            NaN  2008
#  7054            NaN  2008
#
#  [7055 rows x 5 columns],
#          UNITID                                  INSTNM  ADM_RATE  \
#  0       100636      Community College of the Air Force       NaN
#  1       100654                Alabama A & M University    0.4726
#  2       100663     University of Alabama at Birmingham    0.8357
#  3       100690                      Amridge University    0.8750
#  4       100706     University of Alabama in Huntsville    0.7209
#  ...        ...                                     ...       ...
#  7212  44326101        Southeastern Institute-Nashville       NaN
#  7213  44936601                       Make-up Designory       NaN
#  7214  44970001   Dayton School of Medical Massage-Lima       NaN
#  7215  44970002    Cincinnati School of Medical Massage       NaN
#  7216  44970003  Cleveland Institute of Medical Massage       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2009
#  1            4692.0  2009
#  2            5096.0  2009
#  3            8000.0  2009
#  4            6510.0  2009
#  ...             ...   ...
#  7212            NaN  2009
#  7213            NaN  2009
#  7214        17300.0  2009
#  7215        17300.0  2009
#  7216        17300.0  2009
#
#  [7217 rows x 5 columns],
#          UNITID                                INSTNM  ADM_RATE  TUITIONFEE_IN  \
#  0       100636    Community College of the Air Force       NaN            NaN
#  1       100654              Alabama A & M University    0.5129         5800.0
#  2       100663   University of Alabama at Birmingham    0.8243         5806.0
#  3       100690                    Amridge University    0.7143         8360.0
#  4       100706   University of Alabama in Huntsville    0.6614         7492.0
#  ...        ...                                   ...       ...            ...
#  7465  45896402  Strayer University-Charleston Campus       NaN        14085.0
#  7466  45897301             Strayer University-Irving       NaN        14085.0
#  7467  45897302               Strayer University-Katy       NaN        14085.0
#  7468  45897303  Strayer University-Northwest Houston       NaN        14085.0
#  7469  45897304              Strayer University-Plano       NaN        14085.0
#
#        year
#  0     2010
#  1     2010
#  2     2010
#  3     2010
#  4     2010
#  ...    ...
#  7465  2010
#  7466  2010
#  7467  2010
#  7468  2010
#  7469  2010
#
#  [7470 rows x 5 columns],
#          UNITID                                           INSTNM  ADM_RATE  \
#  0       100654                         Alabama A & M University    0.5010
#  1       100663              University of Alabama at Birmingham    0.7223
#  2       100690                               Amridge University       NaN
#  3       100706              University of Alabama in Huntsville    0.6368
#  4       100724                         Alabama State University    0.5080
#  ...        ...                                              ...       ...
#  7741  45920401                                   Unitek College       NaN
#  7742  46163401   Twin Rivers Adult School - Grand Avenue Center       NaN
#  7743  46163402  Twin Rivers Adult School - Arnold Avenue Center       NaN
#  7744  46163403                  Greater Sacramento Urban League       NaN
#  7745  46163404                                            I-TAP       NaN
#
#        TUITIONFEE_IN  year
#  0            6828.0  2011
#  1            6264.0  2011
#  2            8720.0  2011
#  3            8094.0  2011
#  4            8082.0  2011
#  ...             ...   ...
#  7741        17192.0  2011
#  7742            NaN  2011
#  7743            NaN  2011
#  7744            NaN  2011
#  7745            NaN  2011
#
#  [7746 rows x 5 columns],
#          UNITID                                     INSTNM  ADM_RATE  \
#  0       100636         Community College of the Air Force       NaN
#  1       100654                   Alabama A & M University    0.5438
#  2       100663        University of Alabama at Birmingham    0.7223
#  3       100690                         Amridge University       NaN
#  4       100706        University of Alabama in Huntsville    0.7766
#  ...        ...                                        ...       ...
#  7857  47691101  SAE Institute of Technology San Francisco       NaN
#  7858  47701101      Strayer University-Bloomington Campus       NaN
#  7859  47702001       Strayer University-Schaumburg Campus       NaN
#  7860  47702002    Strayer University-Downers Grove Campus       NaN
#  7861  47702003           Strayer University-Aurora Campus       NaN
#
#        TUITIONFEE_IN  year
#  0               NaN  2012
#  1            7182.0  2012
#  2            6798.0  2012
#  3            6800.0  2012
#  4            8794.0  2012
#  ...             ...   ...
#  7857            NaN  2012
#  7858        14985.0  2012
#  7859        14985.0  2012
#  7860        14985.0  2012
#  7861        14985.0  2012
#
#  [7862 rows x 5 columns],
#          UNITID                                         INSTNM  ADM_RATE  \
#  0       100654                       Alabama A & M University    0.8989
#  1       100663            University of Alabama at Birmingham    0.8673
#  2       100690                             Amridge University       NaN
#  3       100706            University of Alabama in Huntsville    0.8062
#  4       100724                       Alabama State University    0.5125
#  ...        ...                                            ...       ...
#  7864  48285703       Georgia Military College-Columbus Campus       NaN
#  7865  48285704       Georgia Military College-Valdosta Campus       NaN
#  7866  48285705  Georgia Military College-Warner Robins Campus       NaN
#  7867  48285706                Georgia Military College-Online       NaN
#  7868  48285707        Georgia Military College-Stone Mountain       NaN
#
#        TUITIONFEE_IN  year
#  0            7182.0  2013
#  1            7206.0  2013
#  2            6870.0  2013
#  3            9192.0  2013
#  4            8720.0  2013
#  ...             ...   ...
#  7864         6276.0  2013
#  7865         5271.0  2013
#  7866         5148.0  2013
#  7867         6900.0  2013
#  7868         5916.0  2013
#
#  [7869 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.5256
#  1       100663                University of Alabama at Birmingham    0.8569
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8203
#  4       100724                           Alabama State University    0.5326
#  ...        ...                                                ...       ...
#  7761  48065701                  Rasmussen College - Overland Park       NaN
#  7762  48154401  National Personal Training Institute of Cleveland       NaN
#  7763  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7764  48400201                        High Desert Medical College       NaN
#  7765  48414501                        Vantage College-San Antonio       NaN
#
#        TUITIONFEE_IN  year
#  0            9096.0  2014
#  1            7510.0  2014
#  2            6900.0  2014
#  3            9158.0  2014
#  4            8720.0  2014
#  ...             ...   ...
#  7761        10764.0  2014
#  7762            NaN  2014
#  7763            NaN  2014
#  7764        29932.0  2014
#  7765            NaN  2014
#
#  [7766 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.6538
#  1       100663                University of Alabama at Birmingham    0.6043
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8120
#  4       100724                           Alabama State University    0.4639
#  ...        ...                                                ...       ...
#  7661  48154401  National Personal Training Institute of Cleveland       NaN
#  7662  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7663  48400201                        High Desert Medical College       NaN
#  7664  48414501                        Vantage College-San Antonio       NaN
#  7665  48621101  American Institute of Pharmaceutical Technolog...       NaN
#
#        TUITIONFEE_IN  year
#  0            9366.0  2015
#  1            7766.0  2015
#  2            6900.0  2015
#  3            9128.0  2015
#  4            8720.0  2015
#  ...             ...   ...
#  7661            NaN  2015
#  7662            NaN  2015
#  7663        31107.0  2015
#  7664            NaN  2015
#  7665            NaN  2015
#
#  [7666 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.8738
#  1       100663                University of Alabama at Birmingham    0.5814
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.7628
#  4       100724                           Alabama State University    0.4590
#  ...        ...                                                ...       ...
#  7233  48305401             Barber School of Pittsburgh - Ambridge       NaN
#  7234  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7235  48400201                        High Desert Medical College       NaN
#  7236  48414501                        Vantage College-San Antonio       NaN
#  7237  48778201                                       BCI - Malden       NaN
#
#        TUITIONFEE_IN  year
#  0            9366.0  2016
#  1            8040.0  2016
#  2            7180.0  2016
#  3            9842.0  2016
#  4            9220.0  2016
#  ...             ...   ...
#  7233            NaN  2016
#  7234            NaN  2016
#  7235            NaN  2016
#  7236            NaN  2016
#  7237            NaN  2016
#
#  [7238 rows x 5 columns],
#          UNITID                                             INSTNM  ADM_RATE  \
#  0       100654                           Alabama A & M University    0.9027
#  1       100663                University of Alabama at Birmingham    0.9181
#  2       100690                                 Amridge University       NaN
#  3       100706                University of Alabama in Huntsville    0.8123
#  4       100724                           Alabama State University    0.9787
#  ...        ...                                                ...       ...
#  7107  48312404                   Arizona State University at Yuma       NaN
#  7108  48387801  Bay Area Medical Academy - San Jose Satellite ...       NaN
#  7109  48400201                        High Desert Medical College       NaN
#  7110  48778201                                       BCI - Malden       NaN
#  7111  49005401          Health Career Institute- Lauderdale Lakes       NaN
#
#        TUITIONFEE_IN  year
#  0            9857.0  2017
#  1            8328.0  2017
#  2            6900.0  2017
#  3           10280.0  2017
#  4           11068.0  2017
#  ...             ...   ...
#  7107            NaN  2017
#  7108            NaN  2017
#  7109            NaN  2017
#  7110            NaN  2017
#  7111        22575.0  2017
#
#  [7112 rows x 5 columns],
#          UNITID                                     INSTNM  ADM_RATE  \
#  0       100654                   Alabama A & M University    0.8986
#  1       100663        University of Alabama at Birmingham    0.9211
#  2       100690                         Amridge University       NaN
#  3       100706        University of Alabama in Huntsville    0.8087
#  4       100724                   Alabama State University    0.9774
#  ...        ...                                        ...       ...
#  6801  48511112          Georgia Military College - Dublin       NaN
#  6802  48511113         Georgia Military College - Eastman       NaN
#  6803  48616901   American College of Barbering - Florence       NaN
#  6804  49005401  Health Career Institute- Lauderdale Lakes       NaN
#  6805  49146401           ABC Adult School - Cabrillo Lane       NaN
#
#        TUITIONFEE_IN  year
#  0            9744.0  2018
#  1            8568.0  2018
#  2            6900.0  2018
#  3           10714.0  2018
#  4           11068.0  2018
#  ...             ...   ...
#  6801         6120.0  2018
#  6802         6120.0  2018
#  6803            NaN  2018
#  6804        21420.0  2018
#  6805            NaN  2018
#
#  [6806 rows x 5 columns]]

# %%
# <6> 
# explore the new dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)
df=pd.concat(df_list)
df.sample(10)
# Out:
#       UNITID                                 INSTNM  ADM_RATE  TUITIONFEE_IN  \
# 6862  457077            Milan Institute-Bakersfield       NaN            NaN
# 2019  170055         Grand Rapids Community College       NaN         1764.0
# 3866  218487   Orangeburg Calhoun Technical College       NaN         2640.0
# 5604  424008               American Pacific College       NaN            NaN
# 2722  179566  Missouri State University-Springfield       NaN            NaN
# 5435  437732               Dallas Nursing Institute       NaN            NaN
# 2623  174817   Saint Mary's University of Minnesota       NaN            NaN
# 4542  236072                  North Seattle College       NaN         2255.0
# 6138  439561           Columbia Green Beauty School       NaN            NaN
# 6615  451750    Bryant & Stratton College-Wauwatosa       NaN        15155.0
#
#       year
# 6862  2011
# 2019  2006
# 3866  2005
# 5604  2007
# 2722  1997
# 5435  2013
# 2623  1996
# 4542  2003
# 6138  2004
# 6615  2010

# %%
df.head(10)
# Out:
#    UNITID                                  INSTNM  ADM_RATE  TUITIONFEE_IN  \
# 0  100636      Community College of the Air Force       NaN            NaN
# 1  100654                Alabama A & M University       NaN            NaN
# 2  100663     University of Alabama at Birmingham       NaN            NaN
# 3  100672  ALABAMA AVIATION AND TECHNICAL COLLEGE       NaN            NaN
# 4  100690                      Amridge University       NaN            NaN
# 5  100706     University of Alabama in Huntsville       NaN            NaN
# 6  100724                Alabama State University       NaN            NaN
# 7  100751               The University of Alabama       NaN            NaN
# 8  100760       Central Alabama Community College       NaN            NaN
# 9  100812                 Athens State University       NaN            NaN
#
#    year
# 0  1996
# 1  1996
# 2  1996
# 3  1996
# 4  1996
# 5  1996
# 6  1996
# 7  1996
# 8  1996
# 9  1996

# %%
df.tail(10)
# Out:
#         UNITID                                     INSTNM  ADM_RATE  \
# 6796  48511107        Georgia Military College - Columbus       NaN
# 6797  48511108    Georgia Military College - Sandersville       NaN
# 6798  48511109         Georgia Military College - Madison       NaN
# 6799  48511110  Georgia Military College - Stone Mountain       NaN
# 6800  48511111    Georgia Military College - Fayetteville       NaN
# 6801  48511112          Georgia Military College - Dublin       NaN
# 6802  48511113         Georgia Military College - Eastman       NaN
# 6803  48616901   American College of Barbering - Florence       NaN
# 6804  49005401  Health Career Institute- Lauderdale Lakes       NaN
# 6805  49146401           ABC Adult School - Cabrillo Lane       NaN
#
#       TUITIONFEE_IN  year
# 6796         6120.0  2018
# 6797         6120.0  2018
# 6798         6120.0  2018
# 6799         6120.0  2018
# 6800         6120.0  2018
# 6801         6120.0  2018
# 6802         6120.0  2018
# 6803            NaN  2018
# 6804        21420.0  2018
# 6805            NaN  2018

# %%
df.isnull().sum()
# Out:
# UNITID                0
# INSTNM                0
# ADM_RATE         118420
# TUITIONFEE_IN     84137
# year                  0
# dtype: int64

# %%
df.describe()
# Out:
#              UNITID      ADM_RATE  TUITIONFEE_IN
# count  1.633310e+05  44911.000000   79194.000000
# mean   9.432395e+05      0.692946   11665.505367
# std    4.571721e+06      0.217062    9985.998016
# min    1.006360e+05      0.000000       0.000000
# 25%    1.633380e+05      0.555000    3776.000000
# 50%    2.127800e+05      0.717500    9285.000000
# 75%    4.075680e+05      0.857100   16146.000000
# max    4.914640e+07      1.000000   74787.000000

# %%
# <7>
# the dataframe contains 22 years of data of all U.S. colleges.
# let's just look at UMBC
# filte/query the dataframe to retrieve only rows that belong to UMBC
# save the UMNC data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.
umbc=df[df['INSTNM'].str.contains("University of Maryland-Baltimore County")]
umbc
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2151  163268  University of Maryland-Baltimore County       NaN
# 2049  163268  University of Maryland-Baltimore County       NaN
# 1982  163268  University of Maryland-Baltimore County       NaN
# 1955  163268  University of Maryland-Baltimore County       NaN
# 1926  163268  University of Maryland-Baltimore County       NaN
# 1915  163268  University of Maryland-Baltimore County    0.6551
# 1893  163268  University of Maryland-Baltimore County    0.6327
# 1873  163268  University of Maryland-Baltimore County    0.5757
# 1830  163268  University of Maryland-Baltimore County    0.7014
# 1819  163268  University of Maryland-Baltimore County    0.7143
# 1799  163268  University of Maryland-Baltimore County    0.7153
# 1779  163268  University of Maryland-Baltimore County    0.6895
# 1767  163268  University of Maryland-Baltimore County    0.7174
# 1745  163268  University of Maryland-Baltimore County    0.6890
# 1710  163268  University of Maryland-Baltimore County    0.6589
# 1694  163268  University of Maryland-Baltimore County    0.6081
# 1660  163268  University of Maryland-Baltimore County    0.6035
# 1629  163268  University of Maryland-Baltimore County    0.6315
# 1610  163268  University of Maryland-Baltimore County    0.5961
# 1555  163268  University of Maryland-Baltimore County    0.5942
# 1510  163268  University of Maryland-Baltimore County    0.5683
# 1478  163268  University of Maryland-Baltimore County    0.6021
# 1415  163268  University of Maryland-Baltimore County    0.5794
#
#       TUITIONFEE_IN  year
# 2151            NaN  1996
# 2049            NaN  1997
# 1982            NaN  1998
# 1955            NaN  1999
# 1926         5490.0  2000
# 1915         5910.0  2001
# 1893         6362.0  2002
# 1873         7388.0  2003
# 1830         8020.0  2004
# 1819         8520.0  2005
# 1799         8622.0  2006
# 1779         8708.0  2007
# 1767         8780.0  2008
# 1745         8872.0  2009
# 1710         9171.0  2010
# 1694         9467.0  2011
# 1660         9764.0  2012
# 1629        10068.0  2013
# 1610        10384.0  2014
# 1555        11006.0  2015
# 1510        11264.0  2016
# 1478        11518.0  2017
# 1415        11778.0  2018

# %%
umbc.head()
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2151  163268  University of Maryland-Baltimore County       NaN
# 2049  163268  University of Maryland-Baltimore County       NaN
# 1982  163268  University of Maryland-Baltimore County       NaN
# 1955  163268  University of Maryland-Baltimore County       NaN
# 1926  163268  University of Maryland-Baltimore County       NaN
#
#       TUITIONFEE_IN  year
# 2151            NaN  1996
# 2049            NaN  1997
# 1982            NaN  1998
# 1955            NaN  1999
# 1926         5490.0  2000

# %%
umbc.tail()
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 1610  163268  University of Maryland-Baltimore County    0.5961
# 1555  163268  University of Maryland-Baltimore County    0.5942
# 1510  163268  University of Maryland-Baltimore County    0.5683
# 1478  163268  University of Maryland-Baltimore County    0.6021
# 1415  163268  University of Maryland-Baltimore County    0.5794
#
#       TUITIONFEE_IN  year
# 1610        10384.0  2014
# 1555        11006.0  2015
# 1510        11264.0  2016
# 1478        11518.0  2017
# 1415        11778.0  2018

# %%
umbc.sample(10)
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 1982  163268  University of Maryland-Baltimore County       NaN
# 1555  163268  University of Maryland-Baltimore County    0.5942
# 1415  163268  University of Maryland-Baltimore County    0.5794
# 1873  163268  University of Maryland-Baltimore County    0.5757
# 1660  163268  University of Maryland-Baltimore County    0.6035
# 2151  163268  University of Maryland-Baltimore County       NaN
# 1510  163268  University of Maryland-Baltimore County    0.5683
# 1926  163268  University of Maryland-Baltimore County       NaN
# 1694  163268  University of Maryland-Baltimore County    0.6081
# 1830  163268  University of Maryland-Baltimore County    0.7014
#
#       TUITIONFEE_IN  year
# 1982            NaN  1998
# 1555        11006.0  2015
# 1415        11778.0  2018
# 1873         7388.0  2003
# 1660         9764.0  2012
# 2151            NaN  1996
# 1510        11264.0  2016
# 1926         5490.0  2000
# 1694         9467.0  2011
# 1830         8020.0  2004

# %%
# <8>
# Explore this UMBC dataframe (# of observations, varibles, head, tail, sample, missing values, statistics,etc.)
umbc.describe()
# Out:
#          UNITID   ADM_RATE  TUITIONFEE_IN
# count      23.0  18.000000      19.000000
# mean   163268.0   0.640694    9004.842105
# std         0.0   0.052728    1825.795421
# min    163268.0   0.568300    5490.000000
# 25%    163268.0   0.597600    8270.000000
# 50%    163268.0   0.632100    8872.000000
# 75%    163268.0   0.689375   10226.000000
# max    163268.0   0.717400   11778.000000

# %%
# <9> 
# Plot UMBC's in-state tution overtime from 1996 to 
2017.
umbc.plot.bar(x="year",y="TUITIONFEE_IN",figsize=(12,5),rot=90)
plt.title("UMBC Tuition")
plt.ylabel("In state tution")
plt.show()

# %%
# <10>
# go back to 5/6/7 and modify the code to look at Johns Hopskins University instead.
# (No code to write here, you just modify the previous cells)
jhu=df[df['INSTNM'].str.contains("Johns Hop")]
jhu
# Out:
#       UNITID                    INSTNM  ADM_RATE  TUITIONFEE_IN  year
# 2139  162928  Johns Hopkins University       NaN            NaN  1996
# 2039  162928  Johns Hopkins University       NaN            NaN  1997
# 1973  162928  Johns Hopkins University       NaN            NaN  1998
# 1946  162928  Johns Hopkins University       NaN            NaN  1999
# 1917  162928  Johns Hopkins University       NaN        24930.0  2000
# 1906  162928  Johns Hopkins University    0.3431        26210.0  2001
# 1884  162928  Johns Hopkins University    0.3506        27390.0  2002
# 1865  162928  Johns Hopkins University    0.3060        28730.0  2003
# 1823  162928  Johns Hopkins University    0.3071        30140.0  2004
# 1812  162928  Johns Hopkins University    0.3509        31620.0  2005
# 1792  162928  Johns Hopkins University    0.2792        33900.0  2006
# 1772  162928  Johns Hopkins University    0.2571        35900.0  2007
# 1760  162928  Johns Hopkins University    0.2609        37700.0  2008
# 1738  162928  Johns Hopkins University    0.2782        39150.0  2009
# 1703  162928  Johns Hopkins University    0.2225        40680.0  2010
# 1687  162928  Johns Hopkins University    0.1940        42280.0  2011
# 1653  162928  Johns Hopkins University    0.1843        43390.0  2012
# 1622  162928  Johns Hopkins University    0.1813        45470.0  2013
# 1603  162928  Johns Hopkins University    0.1608        47060.0  2014
# 1548  162928  Johns Hopkins University    0.1412        48710.0  2015
# 1503  162928  Johns Hopkins University    0.1284        50410.0  2016
# 1473  162928  Johns Hopkins University    0.1254        52170.0  2017
# 1410  162928  Johns Hopkins University    0.1148        53740.0  2018

# %%
# <11> 
# Now, we like to compare UMBC and JHU
# filte/query the dataframe to retrieve only rows that belong to UMBC orJHU
# save the UMNC/JHU data to a new data frame. using a new variable 
# so that the old big data frame is still available for later use.

# %%
# <12>
# Explore the new dataframe (#of observations, varibles, head, tail, sample, missing values, statistics,etc.)
result = pd.concat([umbc, jhu])
result.head(10)
# Out:
#       UNITID                                   INSTNM  ADM_RATE  \
# 2151  163268  University of Maryland-Baltimore County       NaN
# 2049  163268  University of Maryland-Baltimore County       NaN
# 1982  163268  University of Maryland-Baltimore County       NaN
# 1955  163268  University of Maryland-Baltimore County       NaN
# 1926  163268  University of Maryland-Baltimore County       NaN
# 1915  163268  University of Maryland-Baltimore County    0.6551
# 1893  163268  University of Maryland-Baltimore County    0.6327
# 1873  163268  University of Maryland-Baltimore County    0.5757
# 1830  163268  University of Maryland-Baltimore County    0.7014
# 1819  163268  University of Maryland-Baltimore County    0.7143
#
#       TUITIONFEE_IN  year
# 2151            NaN  1996
# 2049            NaN  1997
# 1982            NaN  1998
# 1955            NaN  1999
# 1926         5490.0  2000
# 1915         5910.0  2001
# 1893         6362.0  2002
# 1873         7388.0  2003
# 1830         8020.0  2004
# 1819         8520.0  2005

# %%
result.tail(10)
# Out:
#       UNITID                    INSTNM  ADM_RATE  TUITIONFEE_IN  year
# 1738  162928  Johns Hopkins University    0.2782        39150.0  2009
# 1703  162928  Johns Hopkins University    0.2225        40680.0  2010
# 1687  162928  Johns Hopkins University    0.1940        42280.0  2011
# 1653  162928  Johns Hopkins University    0.1843        43390.0  2012
# 1622  162928  Johns Hopkins University    0.1813        45470.0  2013
# 1603  162928  Johns Hopkins University    0.1608        47060.0  2014
# 1548  162928  Johns Hopkins University    0.1412        48710.0  2015
# 1503  162928  Johns Hopkins University    0.1284        50410.0  2016
# 1473  162928  Johns Hopkins University    0.1254        52170.0  2017
# 1410  162928  Johns Hopkins University    0.1148        53740.0  2018

# %%
# <13>
# Plot the in-state tuition of both UMBC and JHU over the 22 years on the same plot
# This plot will help us compare the two universities.

# %%
table1 = umbc.groupby('year', as_index=False).agg({'TUITIONFEE_IN':'sum'})

# %%
table1_rename = com1.rename(columns={"year": "Year","TUITIONFEE_IN":"UMBC_TUITIONFEE_IN"})
table1_rename
# Out:
#     Year  UMBC_TUITIONFEE_IN
# 0   1996                 0.0
# 1   1997                 0.0
# 2   1998                 0.0
# 3   1999                 0.0
# 4   2000              5490.0
# 5   2001              5910.0
# 6   2002              6362.0
# 7   2003              7388.0
# 8   2004              8020.0
# 9   2005              8520.0
# 10  2006              8622.0
# 11  2007              8708.0
# 12  2008              8780.0
# 13  2009              8872.0
# 14  2010              9171.0
# 15  2011              9467.0
# 16  2012              9764.0
# 17  2013             10068.0
# 18  2014             10384.0
# 19  2015             11006.0
# 20  2016             11264.0
# 21  2017             11518.0
# 22  2018             11778.0

# %%
table2 = jhu.groupby('year', as_index=False).agg({'TUITIONFEE_IN':'sum'})

# %%
table2_rename =table2.rename(columns={"year": "Year","TUITIONFEE_IN":"JHU_TUITIONFEE_IN"})
table2_rename
# Out:
#     Year  JHU_TUITIONFEE_IN
# 0   1996                0.0
# 1   1997                0.0
# 2   1998                0.0
# 3   1999                0.0
# 4   2000            24930.0
# 5   2001            26210.0
# 6   2002            27390.0
# 7   2003            28730.0
# 8   2004            30140.0
# 9   2005            31620.0
# 10  2006            33900.0
# 11  2007            35900.0
# 12  2008            37700.0
# 13  2009            39150.0
# 14  2010            40680.0
# 15  2011            42280.0
# 16  2012            43390.0
# 17  2013            45470.0
# 18  2014            47060.0
# 19  2015            48710.0
# 20  2016            50410.0
# 21  2017            52170.0
# 22  2018            53740.0

# %%
combination = pd.merge(table1_rename,table2_rename,on="Year",how="inner")
combination
# Out:
#     Year  UMBC_TUITIONFEE_IN  JHU_TUITIONFEE_IN
# 0   1996                 0.0                0.0
# 1   1997                 0.0                0.0
# 2   1998                 0.0                0.0
# 3   1999                 0.0                0.0
# 4   2000              5490.0            24930.0
# 5   2001              5910.0            26210.0
# 6   2002              6362.0            27390.0
# 7   2003              7388.0            28730.0
# 8   2004              8020.0            30140.0
# 9   2005              8520.0            31620.0
# 10  2006              8622.0            33900.0
# 11  2007              8708.0            35900.0
# 12  2008              8780.0            37700.0
# 13  2009              8872.0            39150.0
# 14  2010              9171.0            40680.0
# 15  2011              9467.0            42280.0
# 16  2012              9764.0            43390.0
# 17  2013             10068.0            45470.0
# 18  2014             10384.0            47060.0
# 19  2015             11006.0            48710.0
# 20  2016             11264.0            50410.0
# 21  2017             11518.0            52170.0
# 22  2018             11778.0            53740.0

# %%
comb.plot(x="Year", y=["UMBC_TUITIONFEE_IN", "JHU_TUITIONFEE_IN"], kind="bar")
plt.title("TUITION FEE COMPARISION")
plt.ylabel("FEES")
# Out:
# Text(0, 0.5, 'FEES')

# %%
# <14> 
# document your observation/conclusion of the plot (use the following Markdown cell)

# %% [markdown]
# #### Based on my observation I see that the Tution fee for JHU is higher when compared to UMBC
# #### Also the Tution fee for the UMBC has been increasing from yeear to year!

# %%
# The end.
